# %%
import pandas as pd
import numpy as np
from notebook_src.make_preference_matrix import make_preference_df
from pyspark.ml.recommendation import ALS, ALSModel
from pyspark.ml.evaluation import RegressionEvaluator

# %%
df=make_preference_df()

# %%
df
# Out:
#                              _id                        game_id  score  \
# 0       5c09771d933dea68aaeebb68             Grand Theft Auto V      8
# 1       5c09771d933dea68aaeebb69             Grand Theft Auto V      7
# 2       5c09771d933dea68aaeebb6a             Grand Theft Auto V     10
# 3       5c09771d933dea68aaeebb6b             Grand Theft Auto V      4
# 4       5c09771d933dea68aaeebb6c             Grand Theft Auto V      3
# 5       5c09771d933dea68aaeebb6d             Grand Theft Auto V      2
# 6       5c09771d933dea68aaeebb6e             Grand Theft Auto V      7
# 7       5c09771d933dea68aaeebb6f             Grand Theft Auto V      5
# 8       5c09771d933dea68aaeebb70             Grand Theft Auto V      7
# 9       5c09771d933dea68aaeebb71             Grand Theft Auto V      7
# 10      5c09771d933dea68aaeebb72             Grand Theft Auto V     10
# 11      5c09771d933dea68aaeebb73             Grand Theft Auto V     10
# 12      5c09771d933dea68aaeebb74             Grand Theft Auto V     10
# 13      5c09771d933dea68aaeebb75             Grand Theft Auto V      8
# 14      5c09771d933dea68aaeebb76             Grand Theft Auto V      8
# 15      5c09771d933dea68aaeebb77             Grand Theft Auto V      8
# 16      5c09771d933dea68aaeebb78             Grand Theft Auto V     10
# 17      5c09771d933dea68aaeebb79             Grand Theft Auto V      8
# 18      5c09771d933dea68aaeebb7a             Grand Theft Auto V     10
# 19      5c09771d933dea68aaeebb7b             Grand Theft Auto V     10
# 20      5c09771d933dea68aaeebb7c             Grand Theft Auto V     10
# 21      5c09771d933dea68aaeebb7d             Grand Theft Auto V     10
# 22      5c09771d933dea68aaeebb7e             Grand Theft Auto V     10
# 23      5c09771d933dea68aaeebb7f             Grand Theft Auto V     10
# 24      5c09771d933dea68aaeebb80             Grand Theft Auto V      0
# 25      5c09771d933dea68aaeebb81             Grand Theft Auto V      7
# 26      5c09771d933dea68aaeebb82             Grand Theft Auto V      6
# 27      5c09771d933dea68aaeebb83             Grand Theft Auto V      7
# 28      5c09771d933dea68aaeebb84             Grand Theft Auto V      7
# 29      5c09771d933dea68aaeebb85             Grand Theft Auto V     10
# ...                          ...                            ...    ...
# 109240  5c116b44933dea08df197e8f  Woodle Tree Adventures Deluxe      9
# 109241  5c116b44933dea08df197e90  Woodle Tree Adventures Deluxe     10
# 109242  5c116b44933dea08df197e91  Woodle Tree Adventures Deluxe      9
# 109243  5c116b44933dea08df197e92  Woodle Tree Adventures Deluxe      4
# 109244  5c116b44933dea08df197e93  Woodle Tree Adventures Deluxe      2
# 109245  5c116b44933dea08df197e94  Woodle Tree Adventures Deluxe      3
# 109246  5c116b44933dea08df197e95                         Tennis     10
# 109247  5c116b44933dea08df197e96                        Awkward      0
# 109248  5c116b44933dea08df197e97         Vroom in the Night Sky      2
# 109249  5c116b44933dea08df197e98         Vroom in the Night Sky      0
# 109250  5c116b44933dea08df197e99         Vroom in the Night Sky      0
# 109251  5c116b44933dea08df197e9a         Vroom in the Night Sky      1
# 109252  5c116b44933dea08df197e9b         Vroom in the Night Sky      1
# 109253  5c116b44933dea08df197e9c         Vroom in the Night Sky      0
# 109254  5c116b44933dea08df197e9d         Vroom in the Night Sky      0
# 109255  5c116b44933dea08df197e9e         Vroom in the Night Sky      2
# 109256  5c116b44933dea08df197e9f         Vroom in the Night Sky      3
# 109257  5c116b44933dea08df197ea0         Vroom in the Night Sky      0
# 109258  5c116b44933dea08df197ea1         Vroom in the Night Sky      0
# 109259  5c116b44933dea08df197ea2         Vroom in the Night Sky     10
# 109260  5c116b44933dea08df197ea3         Vroom in the Night Sky      9
# 109261  5c116b44933dea08df197ea4         Vroom in the Night Sky     10
# 109262  5c116b44933dea08df197ea5         Vroom in the Night Sky     10
# 109263  5c116b44933dea08df197ea6         Vroom in the Night Sky     10
# 109264  5c116b44933dea08df197ea7         Vroom in the Night Sky     10
# 109265  5c116b44933dea08df197ea8         Vroom in the Night Sky     10
# 109266  5c116b44933dea08df197ea9         Vroom in the Night Sky      0
# 109267  5c116b44933dea08df197eaa         Vroom in the Night Sky      2
# 109268  5c116b44933dea08df197eab         Vroom in the Night Sky      0
# 109269  5c116b44933dea08df197eac         Vroom in the Night Sky     10
#
#                 user_id  game_number  user_number
# 0             J4MESOX4D         1026        25541
# 1         CardinalStorm         1026         3259
# 2              DareJedi         1026        12477
# 3         MaxBenevolent         1026        30190
# 4          BVGNOfficial         1026        51259
# 5              stedee73         1026         2801
# 6          NZAnimeManga         1026        49962
# 7           evolution98         1026        42936
# 8          SotirisKmsGR         1026         9517
# 9       AbradolfLinkler         1026        54319
# 10            jessda123         1026        54785
# 11            Zwtich_TV         1026         3890
# 12          jevoapartir         1026         1776
# 13      Red-Opposom-098         1026        34793
# 14                me5ut         1026        49443
# 15                Fryto         1026        45211
# 16               tgchan         1026         6853
# 17            herrmoekl         1026        32890
# 18           DSouls_guy         1026         2224
# 19          tonyneculai         1026        22067
# 20      EvilstuffGaming         1026        45234
# 21              XXXibil         1026        53087
# 22           CubWoods15         1026        49434
# 23           Duke_Nukem         1026        33071
# 24      rodericrinehart         1026        16237
# 25              Nick530         1026           12
# 26            Vanpire73         1026        35513
# 27             system11         1026        36931
# 28      reviewobsession         1026        32832
# 29        MaxPayneIsGod         1026         1989
# ...                 ...          ...          ...
# 109240   LuciusGambling         2087        33486
# 109241  marianipaganini         2087        17005
# 109242  supersayanblueg         2087        11180
# 109243       luigicap10         2087        54830
# 109244             insx         2087        31573
# 109245    craigoryegory         2087        28148
# 109246         etansteg         1020         2206
# 109247     nefarious411         1322        10715
# 109248      SkinnyPen15         1142        29554
# 109249      AlexToral_F         1142        36152
# 109250  pat2004reviewer         1142        19757
# 109251          Duduoro         1142         7378
# 109252       luigicap10         1142        54830
# 109253         eli32109         1142        27757
# 109254      Robloxfan27         1142        24849
# 109255     mikerbiker62         1142         2281
# 109256         ByYuxiSs         1142         4864
# 109257      toonlinkman         1142        53061
# 109258   AllISayIsRight         1142         7124
# 109259      MA3GNetwork         1142        27823
# 109260       wariowario         1142        49934
# 109261  thedonald112915         1142        27195
# 109262      TheLastofMe         1142        22415
# 109263           BlitzR         1142        38119
# 109264        Yaywalter         1142        44780
# 109265       kennymarth         1142        23521
# 109266         Ljungman         1142        14017
# 109267        tsdenizen         1142        20578
# 109268        IndieCrit         1142        18612
# 109269         riccyjay         1142         4898
#
# [109270 rows x 6 columns]

# %%
#print(len(df.user_id.unique()), len(df.game_id.unique()))

# %% [markdown]
# Unique users : 55272
#
# Unique games : 2289

# %%
spark_df=spark.createDataFrame(df[['game_number', 'user_number', 'score']])

# %%
spark_df.show()
# Out:
# +-----------+-----------+-----+
# |game_number|user_number|score|
# +-----------+-----------+-----+
# |       1026|      25541|    8|
# |       1026|       3259|    7|
# |       1026|      12477|   10|
# |       1026|      30190|    4|
# |       1026|      51259|    3|
# |       1026|       2801|    2|
# |       1026|      49962|    7|
# |       1026|      42936|    5|
# |       1026|       9517|    7|
# |       1026|      54319|    7|
# |       1026|      54785|   10|
# |       1026|       3890|   10|
# |       1026|       1776|   10|
# |       1026|      34793|    8|
# |       1026|      49443|    8|
# |       1026|      45211|    8|
# |       1026|       6853|   10|
# |       1026|      32890|    8|
# |       1026|       2224|   10|
# |       1026|      22067|   10|
# +-----------+-----------+-----+
# only showing top 20 rows

# %%
(training, test) = spark_df.randomSplit([0.8, 0.2])

# %%
als = ALS(maxIter=15, 
          regParam=0.5, 
          rank=100,
          userCol="user_number",
          itemCol="game_number",
          ratingCol="score",
          coldStartStrategy="drop")

# %%
model = als.fit(training)

# %%
model.save('als_model.pkl')

# %%
model=ALSModel.load('als_model.pkl')

# %%
predictions = model.transform(test)

# %%
evaluator = RegressionEvaluator(metricName="rmse", 
                                labelCol="score",
                                predictionCol="prediction")

# %%
rmse = evaluator.evaluate(predictions)

# %%
rmse
# Out:
# 3.049170885807583

# %%
user_factors = model.userFactors.toPandas()
item_factors = model.itemFactors.toPandas()

# %%
item_arr=np.array(item_factors['features'].tolist())
user_arr=np.array(user_factors['features'].tolist())

# %%
np.save('item_arr.npy', item_arr)

# %%
item_arr=np.load('item_arr.npy')

# %% [markdown]
# # Create example for model to give prediction to

# %%
sample1 = {'Destiny 2: Forsaken': 8,
         "Everybody's Golf": 8,
         "XCOM 2": 9,
         "NBA 2K17": 10,
         "Marvel's Spider-Man":6}

sample2 = {'Far Cry 5': 8,
         "Madden NFL 16": 6,
         "Tricky Towers": 8,
         "Fallout 4": 9,
         "Persona 5":10}

sample3 = {'Fallout 4': 10}

# %%
for key in sample2:
    print(df[df['game_id']==key]['game_id'].unique())
# Out:
# ['Far Cry 5']
# ['Madden NFL 16']
# ['Tricky Towers']
# ['Fallout 4']
# ['Persona 5']

# %%
from pyspark.sql import Row

def insert_user_prefs(prefs={}):
    """Insert a new user's scores into the spark df with the rest
        of the user scores
        
        This is also completely irrelevant for giving a recommendation
        but was a nice practice in working with spark dataframes"""
    for key in prefs:
        nums=[(
            int(df[df['game_id']==key].game_number.unique()),
            len(df.user_id.unique())+1,
            sample[key]
               )]
        
        rdd=sc.parallelize(nums)
        entry=Row('game_number', 'user_number', 'score')
        new=rdd.map(lambda x: entry(*x))

        new_row=spark.createDataFrame(new)

        spark_df=spark_df.union(new_row)
    
    
# 'Game ID':  int(df[df['game_id']==key].game_number.unique()),
# 'USER ID':  len(df.user_id.unique())+1,
# 'SCORE':    sample[key])

# %%
def create_user_vector(prefs={}, item_factors=item_arr):
    game_ids=[]
    scores=[]
    for key in prefs:
        game_ids.append(int(df[df['game_id']==key].game_number.unique()))
        scores.append(prefs[key])
    ratings=np.array(scores)
    
    return ratings, item_factors[game_ids], game_ids

# %%
scores_vec, user_item_arr, game_ids = create_user_vector(prefs=sample3)

# %%
scores_vec.shape, user_item_arr.shape
# Out:
# ((1,), (1, 100))

# %%
X, residuals, rank, s =np.linalg.lstsq(user_item_arr, scores_vec, rcond=None)

# %%
user_factors=X

# %%
def predict_new_user(user_factors, item_arr):
    new_factor_list = []
    for i in range(len(item_arr)):
        new_factor_list.append(np.dot(user_factors, item_arr[i]))
    new_user_df = pd.DataFrame([new_factor_list], index=['new_user'])
    return np.array(new_factor_list)

# %%
test_arr = predict_new_user(user_factors, item_arr)

# %%
test_arr = np.delete(test_arr, game_ids)

# %%
test_arr.argsort()[-5:][::-1]
# Out:
# array([941, 132, 581, 593, 352])

# %%
for ind in test_arr.argsort()[-5:][::-1]:
    print(df[df['game_number']==ind]['game_id'].unique(),)
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-38-6088d3b0bee9> in <module>()
# ----> 1 for ind in test_arr.argsort()[-5:][::-1]:
#       2     print(df[df['game_number']==ind]['game_id'].unique(),)
#
# NameError: name 'test_arr' is not defined

# %%
import src.collaborative_filtering

# %%
test_vec= src.collaborative_filtering.make_prefernce_vector(sample1)

# %%
test_vec
# Out:
# array([5.06104714, 7.77494894, 3.39601426, ..., 7.48739287, 8.84294797,
#        8.51642464])

# %%
for ind in test_vec.argsort()[-5:][::-1]:
    print(df[df['game_number']==ind]['game_id'].unique()[0])
# Out:
# Yasai Ninja
# Mortal Blitz
# ClusterTruck
# Dead Alliance
# Narcosis

# %%
src.collaborative_filtering.give_recommendation(sample2)
# Out:
# ['Super Bomberman R',
#  'BlazBlue: Central Fiction',
#  'LocoCycle',
#  'Wayward Sky',
#  'Fighter Within']
