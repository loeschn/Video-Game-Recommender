# %%
import requests
import pymongo
import pandas as pd

# %%
mc = pymongo.MongoClient()
db = mc['game_data']

# %% [markdown]
# curl -X GET --header "Accept: application/json" --header "user-key: 1cca0ffb6c7bbc063e1ae12727218933" "https://api-2445582011268.apicast.io/games/"

# %%
url = "https://api-2445582011268.apicast.io/games/77206"
key_word_url  = "https://api-2445582011268.apicast.io/keywords/1102"

class ScrapingException(Exception):
    pass

def api_request(url, params=None):
    """Make an IGDB API request."""
    headers = {'Accept': 'application/json', 
               "user-key": '1cca0ffb6c7bbc063e1ae12727218933'}
    response = requests.get(url, headers=headers, params=params)
    if response.status_code != 200:
        raise ScrapingException(f"Error: status code {response.status_code}\n\nContent:\n{response.content}")
    return response.json()

# %%
def api_keywords(keyword_id=""):
    """Get keyword data for keyword_id."""
    url = f"https://api-2445582011268.apicast.io/keywords/{keyword_id}"
    return api_request(url)

# %%
def api_endpoint(endpoint="", endpoint_id=""):
    """Make a request for an endpoint & endpoint_id"""
    url = f"https://api-2445582011268.apicast.io/{endpoint}/{endpoint_id}"
    return api_request(url)

# %%
api_endpoint(endpoint='game_modes', endpoint_id=1)
# Out:
# [{'id': 1,
#   'name': 'Single player',
#   'created_at': 1298968834000,
#   'updated_at': 1323289216000,
#   'slug': 'single-player',
#   'url': 'https://www.igdb.com/game_modes/single-player',
#   'games': [37,
#    6,
#    38,
#    5,
#    35,
#    13,
#    11,
#    42,
#    109,
#    111,
#    112,
#    113,
#    78,
#    115,
#    116,
#    120,
#    122,
#    126,
#    133,
#    134,
#    142,
#    139,
#    150,
#    154,
#    106,
#    208,
#    152,
#    207,
#    205,
#    155,
#    204,
#    157,
#    159,
#    203,
#    82,
#    81,
#    177,
#    136,
#    90,
#    213,
#    220,
#    218,
#    219,
#    357,
#    360,
#    343,
#    364,
#    370,
#    371,
#    368,
#    373,
#    385,
#    387,
#    393,
#    390,
#    424,
#    426,
#    427,
#    428,
#    429,
#    284,
#    435,
#    448,
#    449,
#    450,
#    451,
#    452,
#    472,
#    299,
#    291,
#    324,
#    337,
#    303,
#    211,
#    240,
#    321,
#    340,
#    297,
#    67,
#    277,
# ...

# %%
api_keywords(4882)
# Out:
# [{'id': 4882,
#   'name': 'pax west 2016',
#   'created_at': 1507204999044,
#   'updated_at': 1507204999044,
#   'slug': 'pax-west-2016',
#   'url': 'https://www.igdb.com/categories/pax-west-2016',
#   'games': [342,
#    359,
#    1081,
#    1270,
#    1644,
#    1818,
#    1939,
#    2605,
#    2690,
#    3152,
#    3153,
#    3222,
#    3227,
#    5266,
#    5587,
#    6066,
#    6451,
#    6655,
#    6732,
#    6748,
#    7202,
#    7323,
#    7709,
#    8258,
#    8288,
#    8590,
#    8652,
#    8816,
#    8965,
#    8983,
#    9062,
#    9101,
#    9181,
#    9336,
#    9497,
#    9498,
#    9525,
#    9527,
#    9598,
#    9609,
#    9728,
#    9730,
#    9815,
#    9945,
#    10128,
#    10148,
#    10232,
#    10233,
#    10239,
#    10403,
#    10960,
#    10964,
#    11064,
#    11076,
#    11078,
#    11118,
#    11120,
#    11122,
#    11131,
#    11134,
#    11156,
#    11157,
#    11161,
#    11162,
#    11177,
#    11182,
#    11186,
#    11200,
#    11201,
# ...

# %%
def api_genre(genre_id=""):
    """Get genre data for genre_id."""
    url = f"https://api-2445582011268.apicast.io/genres/{genre_id}"
    return api_request(url)

# %%
api_genre(4)
# Out:
# [{'id': 4,
#   'name': 'Fighting',
#   'created_at': 1297639288000,
#   'updated_at': 1323289215000,
#   'slug': 'fighting',
#   'url': 'https://www.igdb.com/genres/fighting',
#   'games': [111296,
#    119,
#    359,
#    360,
#    10,
#    455,
#    510,
#    105418,
#    884,
#    1013,
#    1051,
#    1065,
#    1142,
#    1239,
#    1242,
#    1243,
#    1244,
#    1245,
#    1246,
#    1247,
#    1249,
#    1235,
#    1238,
#    1241,
#    1248,
#    1240,
#    1237,
#    1383,
#    1413,
#    1414,
#    1417,
#    1568,
#    1616,
#    1612,
#    1617,
#    1622,
#    1621,
#    1875,
#    1790,
#    1899,
#    1918,
#    1934,
#    1971,
#    2048,
#    2066,
#    1628,
#    2194,
#    2195,
#    2243,
#    2247,
#    2253,
#    2252,
#    2254,
#    2275,
#    1551,
#    1547,
#    2326,
#    1965,
#    2358,
#    2387,
#    7496,
#    8537,
#    8585,
#    2413,
#    2482,
#    7488,
#    8397,
#    8407,
#    8536,
#    4546,
#    5627,
#    5735,
#    5745,
#    1389,
# ...

# %%
def api_games(game_id=""):
    """Get game data for game_id."""
    url = f"https://api-2445582011268.apicast.io/games/{game_id}"
    return api_request(url)

# %%
games = db['games']
keywords = db['keywords']

# %%
keyword_ids = [1102,
   1471,
   1928,
   2044,
   2762,
   4346,
   4767,
   4959,
   6001,
   6019,
   6078,
   9349,
   12350,
   13017]

for keyword_id in keyword_ids:
    keywords.insert_many(api_keywords(keyword_id))

# %%
keyword_data = list(keywords.find())

# %%
keyword_data[1]
# Out:
# {'_id': ObjectId('5be63097933dea1b37582957'),
#  'id': 1471,
#  'name': 'real-time strategy',
#  'created_at': 1428781239370,
#  'updated_at': 1428781239370,
#  'slug': 'real-time-strategy',
#  'url': 'https://www.igdb.com/categories/real-time-strategy',
#  'games': [35,
#   36,
#   85,
#   86,
#   87,
#   89,
#   129,
#   130,
#   131,
#   132,
#   133,
#   144,
#   159,
#   174,
#   212,
#   230,
#   235,
#   239,
#   242,
#   245,
#   257,
#   276,
#   295,
#   298,
#   299,
#   300,
#   311,
#   321,
#   324,
#   327,
#   331,
#   340,
#   432,
#   436,
#   437,
#   438,
#   440,
#   441,
#   442,
#   443,
#   444,
#   456,
#   457,
#   458,
#   465,
#   466,
#   468,
#   470,
#   587,
#   595,
#   596,
#   599,
#   606,
#   639,
#   647,
#   649,
#   654,
#   662,
#   663,
#   670,
#   676,
#   678,
#   682,
#   707,
#   734,
#   735,
#   749,
#   759,
#   767,
#   775,
#   781,
#   791,
#   848,
#   849,
#   853,
#   867,
#   868,
#   872,
#   888,
#   900,
#   918,
#   929,
# ...

# %%
pprint(api_games(1467))
# Out:
# [{'alternative_names': [{'name': '罪と罰～地球の継承者～'}],
#   'category': 0,
#   'collection': 308,
#   'cover': {'cloudinary_id': 'juyuopefpodfmyoh6ejf',
#             'height': 348,
#             'url': '//images.igdb.com/igdb/image/upload/t_thumb/juyuopefpodfmyoh6ejf.jpg',
#             'width': 250},
#   'created_at': 1349634299368,
#   'developers': [761, 861],
#   'first_release_date': 974764800000,
#   'game_modes': [1, 2],
#   'games': [103298,
#             103281,
#             95340,
#             32902,
#             103020,
#             28029,
#             103301,
#             306,
#             24491,
#             19341],
#   'genres': [5],
#   'id': 1467,
#   'keywords': [93],
#   'name': 'Sin and Punishment',
#   'platforms': [4, 41, 47, 5],
#   'player_perspectives': [2],
#   'popularity': 1.333333333333333,
#   'publishers': [70],
#   'rating': 79.9507348339942,
#   'rating_count': 5,
#   'release_dates': [{'category': 0,
#                      'date': 1441238400000,
# ...

# %%
api_keywords(1102)
# Out:
# [{'id': 1102,
#   'name': 'religion',
#   'created_at': 1403127958181,
#   'updated_at': 1403127958181,
#   'slug': 'religion',
#   'url': 'https://www.igdb.com/categories/religion',
#   'games': [20,
#    21,
#    37,
#    38,
#    56,
#    59,
#    74,
#    85,
#    86,
#    87,
#    88,
#    89,
#    112,
#    113,
#    120,
#    127,
#    230,
#    274,
#    282,
#    293,
#    308,
#    324,
#    418,
#    440,
#    441,
#    444,
#    447,
#    480,
#    482,
#    491,
#    499,
#    507,
#    538,
#    549,
#    550,
#    551,
#    552,
#    633,
#    684,
#    686,
#    740,
#    863,
#    865,
#    985,
#    989,
#    1029,
#    1130,
#    1131,
#    1149,
#    1175,
#    1182,
#    1216,
#    1250,
#    1252,
#    1254,
#    1262,
#    1291,
#    1342,
#    1441,
#    1442,
#    1831,
#    1834,
#    1876,
#    1961,
#    2132,
#    2211,
#    2261,
#    2262,
#    2263,
#    2467,
#    2481,
#    2594,
#    2656,
#    2689,
#    2846,
#    2899,
#    2918,
#    3103,
# ...

# %%
response = requests.get(key_word_url, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-fa712f54315a> in <module>()
# ----> 1 response = requests.get(key_word_url, headers=headers)
#
# NameError: name 'headers' is not defined

# %%
response.status_code
# Out:
# 200

# %%
resp

# %%
response.json()
# Out:
# [{'id': 1102,
#   'name': 'religion',
#   'created_at': 1403127958181,
#   'updated_at': 1403127958181,
#   'slug': 'religion',
#   'url': 'https://www.igdb.com/categories/religion',
#   'games': [20,
#    21,
#    37,
#    38,
#    56,
#    59,
#    74,
#    85,
#    86,
#    87,
#    88,
#    89,
#    112,
#    113,
#    120,
#    127,
#    230,
#    274,
#    282,
#    293,
#    308,
#    324,
#    418,
#    440,
#    441,
#    444,
#    447,
#    480,
#    482,
#    491,
#    499,
#    507,
#    538,
#    549,
#    550,
#    551,
#    552,
#    633,
#    684,
#    686,
#    740,
#    863,
#    865,
#    985,
#    989,
#    1029,
#    1130,
#    1131,
#    1149,
#    1175,
#    1182,
#    1216,
#    1250,
#    1252,
#    1254,
#    1262,
#    1291,
#    1342,
#    1441,
#    1442,
#    1831,
#    1834,
#    1876,
#    1961,
#    2132,
#    2211,
#    2261,
#    2262,
#    2263,
#    2467,
#    2481,
#    2594,
#    2656,
#    2689,
#    2846,
#    2899,
#    2918,
#    3103,
# ...

# %% [markdown]
# # Exploring platform data

# %%
platform_url  = "https://api-2445582011268.apicast.io/platforms"

def api_platforms(platform_id=""):
    """Get platform data for platform_id."""
    url = f"https://api-2445582011268.apicast.io/platforms/{platform_id}"
    return api_request(url)

# %%
api_platforms(4)
# Out:
# [{'id': 4,
#   'name': 'Nintendo 64',
#   'slug': 'n64',
#   'url': 'https://www.igdb.com/platforms/n64',
#   'created_at': 1297639288000,
#   'updated_at': 1517315100595,
#   'alternative_name': 'N64',
#   'generation': 5,
#   'games': [1257,
#    1258,
#    1259,
#    1130,
#    1131,
#    154,
#    164,
#    188,
#    333,
#    330,
#    699,
#    779,
#    811,
#    812,
#    843,
#    913,
#    914,
#    948,
#    951,
#    647,
#    880,
#    705,
#    1029,
#    1030,
#    1286,
#    1292,
#    1355,
#    1467,
#    1641,
#    1622,
#    1842,
#    2289,
#    2327,
#    2328,
#    2329,
#    2342,
#    2713,
#    2714,
#    2715,
#    2723,
#    2786,
#    2792,
#    2847,
#    2858,
#    3471,
#    3056,
#    1326,
#    2542,
#    3290,
#    3328,
#    3330,
#    3331,
#    3334,
#    3335,
#    3336,
#    3337,
#    3338,
#    3339,
#    3340,
#    3341,
#    3342,
#    3343,
#    3344,
#    3345,
#    3346,
#    3348,
#    3366,
#    3367,
#    3368,
#    3369,
#    3370,
# ...

# %%
platforms = db['platforms']

# %%
platform_ids = list(range(120))

for platform_id in platform_ids:
    platform_data = api_platforms(platform_id)
    if platform_data:
        platforms.insert_many(platform_data)

# %%
platforms.find_one()
# Out:
# {'_id': ObjectId('5bea413d933dea0e0b3dbb97'),
#  'id': 3,
#  'name': 'Linux',
#  'logo': {'url': '//images.igdb.com/igdb/image/upload/t_thumb/lyn1jv2cu6hjoaikatdv.jpg',
#   'cloudinary_id': 'lyn1jv2cu6hjoaikatdv',
#   'width': 1344,
#   'height': 742},
#  'slug': 'linux',
#  'url': 'https://www.igdb.com/platforms/linux',
#  'created_at': 1297639288000,
#  'updated_at': 1392982362499,
#  'website': 'http://www.linux.org',
#  'summary': 'Linux is a free and open-source (FOSS/FLOSS) Operating System. In a more precise and complex definition, Linux is an open-source OS kernel on which a large variety of Operating Systems (known as Linux distributions) are built.',
#  'alternative_name': 'GNU/Linux',
#  'games': [34911,
#   7706,
#   280,
#   2974,
#   35044,
#   35061,
#   285,
#   35118,
#   35092,
#   35117,
#   35111,
#   767,
#   781,
#   763,
#   851,
#   799,
#   857,
#   927,
#   926,
#   863,
#   1018,
#   1024,
#   1054,
#   5506,
#   1331,
#   11795,
#   2247,
#   2243,
# ...

# %%
platforms.find_one()['name'], len(platforms.find_one()['games'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-73fd07dc2b5b> in <module>()
# ----> 1 platforms.find_one()['name'], len(platforms.find_one()['games'])
#
# NameError: name 'platforms' is not defined

# %%
from pprint import pprint

# %%
cursor = platforms.find()
for document in cursor: 
    print(document['name'], len(document['games']))
# Out:
# Linux 4008
# Nintendo 64 423
# Wii 1980
# PC (Microsoft Windows) 25179
# PlayStation 1714
# PlayStation 2 2349
# PlayStation 3 2327
# Xbox 955
# Xbox 360 1940
# PC DOS 2048
# Mac 7250
# Commodore C64/128 2133
# Amiga 1919
# Nintendo Entertainment System (NES) 1450
# Super Nintendo Entertainment System (SNES) 1620
# Nintendo DS 1460
# Nintendo GameCube 660
# Game Boy Color 529
# Dreamcast 324
# Game Boy Advance 1455
# Amstrad CPC 1303
# ZX Spectrum 1342
# MSX 659
# Sega Mega Drive/Genesis 942
# Sega 32X 37
# Sega Saturn 406
# Game Boy 582
# Android 1819
# Sega Game Gear 310
# Xbox Live Arcade 409
# Nintendo 3DS 1492
# PlayStation Portable 1077
# iOS 2532
# Wii U 1167
# N-Gage 54
# Tapwave Zodiac 3
# PlayStation Network 1470
# PlayStation Vita 799
# Virtual Console (Nintendo) 256
# PlayStation 4 2470
# Xbox One 1877
# 3DO Interactive Multiplayer 169
# Family Computer Disk System 116
# Arcade 2338
# MSX2 23
# Mobile 177
# WiiWare 372
# WonderSwan 118
# Super Famicom 313
# ...

# %%
platforms.count()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 107

# %%
[(doc['name'], len(doc['games']) for doc in platforms.find()]
# Out:
#   File "<ipython-input-81-a0e7d5847db8>", line 1
#     [(doc['name'], len(doc['games']) for doc in platforms.find()]
#                                        ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame(list(platforms.find()))

# %%
for i in range(107):
    print(df.name[i], len(df.games[i]))
# Out:
# Linux 4008
# Nintendo 64 423
# Wii 1980
# PC (Microsoft Windows) 25179
# PlayStation 1714
# PlayStation 2 2349
# PlayStation 3 2327
# Xbox 955
# Xbox 360 1940
# PC DOS 2048
# Mac 7250
# Commodore C64/128 2133
# Amiga 1919
# Nintendo Entertainment System (NES) 1450
# Super Nintendo Entertainment System (SNES) 1620
# Nintendo DS 1460
# Nintendo GameCube 660
# Game Boy Color 529
# Dreamcast 324
# Game Boy Advance 1455
# Amstrad CPC 1303
# ZX Spectrum 1342
# MSX 659
# Sega Mega Drive/Genesis 942
# Sega 32X 37
# Sega Saturn 406
# Game Boy 582
# Android 1819
# Sega Game Gear 310
# Xbox Live Arcade 409
# Nintendo 3DS 1492
# PlayStation Portable 1077
# iOS 2532
# Wii U 1167
# N-Gage 54
# Tapwave Zodiac 3
# PlayStation Network 1470
# PlayStation Vita 799
# Virtual Console (Nintendo) 256
# PlayStation 4 2470
# Xbox One 1877
# 3DO Interactive Multiplayer 169
# Family Computer Disk System 116
# Arcade 2338
# MSX2 23
# Mobile 177
# WiiWare 372
# WonderSwan 118
# Super Famicom 313
# ...

# %%
pprint(list(df.name))
# Out:
# ['Linux',
#  'Nintendo 64',
#  'Wii',
#  'PC (Microsoft Windows)',
#  'PlayStation',
#  'PlayStation 2',
#  'PlayStation 3',
#  'Xbox',
#  'Xbox 360',
#  'PC DOS',
#  'Mac',
#  'Commodore C64/128',
#  'Amiga',
#  'Nintendo Entertainment System (NES)',
#  'Super Nintendo Entertainment System (SNES)',
#  'Nintendo DS',
#  'Nintendo GameCube',
#  'Game Boy Color',
#  'Dreamcast',
#  'Game Boy Advance',
#  'Amstrad CPC',
#  'ZX Spectrum',
#  'MSX',
#  'Sega Mega Drive/Genesis',
#  'Sega 32X',
#  'Sega Saturn',
#  'Game Boy',
#  'Android',
#  'Sega Game Gear',
#  'Xbox Live Arcade',
#  'Nintendo 3DS',
#  'PlayStation Portable',
#  'iOS',
#  'Wii U',
#  'N-Gage',
#  'Tapwave Zodiac',
#  'PlayStation Network',
#  'PlayStation Vita',
#  'Virtual Console (Nintendo)',
#  'PlayStation 4',
#  'Xbox One',
#  '3DO Interactive Multiplayer',
#  'Family Computer Disk System',
#  'Arcade',
#  'MSX2',
#  'Mobile',
#  'WiiWare',
#  'WonderSwan',
#  'Super Famicom',
#  'Atari 2600',
#  'Atari 7800',
# ...

# %%
favorite_platforms = ['Nintendo 64',
                    'Wii',
                    'PC (Microsoft Windows)',
                    'PlayStation',
                    'PlayStation 2',
                    'PlayStation 3',
                    'Xbox',
                    'Xbox 360',
                    'PC DOS',
                    'Mac',
                    'Nintendo Entertainment System (NES)',
                    'Super Nintendo Entertainment System (SNES)',
                    'Nintendo DS',
                    'Nintendo GameCube',
                    'Game Boy Color',
                    'Dreamcast',
                    'Game Boy Advance',
                    'Sega Saturn',
                    'Game Boy',
                    'Nintendo 3DS',
                    'PlayStation Portable',
                    'Wii U',
                    'PlayStation 4',
                    'Xbox One','
                    'SteamOS']

# %%
df.iloc[0]
# Out:
# _id                                          5bea413d933dea0e0b3dbb97
# alternative_name                                            GNU/Linux
# created_at                                              1297639288000
# games               [34911, 7706, 280, 2974, 35044, 35061, 285, 35...
# generation                                                        NaN
# id                                                                  3
# logo                {'url': '//images.igdb.com/igdb/image/upload/t...
# name                                                            Linux
# slug                                                            linux
# summary             Linux is a free and open-source (FOSS/FLOSS) O...
# updated_at                                              1392982362499
# url                              https://www.igdb.com/platforms/linux
# versions            [{'name': 'Initial version', 'slug': 'initial-...
# ...

# %%
ps4_games = list(df[df.name=='PlayStation 4'].games)

# %%
ps4_games[0]
# Out:
# [2033,
#  8500,
#  2957,
#  1979,
#  2920,
#  3152,
#  16735,
#  3256,
#  18655,
#  3094,
#  4,
#  16765,
#  6632,
#  4756,
#  4754,
#  1887,
#  6030,
#  4755,
#  21729,
#  4071,
#  386,
#  8992,
#  5895,
#  17522,
#  1968,
#  3042,
#  7574,
#  28513,
#  54489,
#  36300,
#  6008,
#  4844,
#  6976,
#  7380,
#  7587,
#  4674,
#  17145,
#  6147,
#  3188,
#  3146,
#  4845,
#  121,
#  5541,
#  5333,
#  5328,
#  7171,
#  7685,
#  27512,
#  7208,
#  5330,
#  5327,
#  4786,
#  7614,
#  1354,
#  8598,
#  8467,
#  1981,
#  7897,
#  14878,
#  11203,
#  3025,
#  2050,
#  6707,
#  1267,
#  19916,
#  8409,
#  52555,
#  3095,
#  8507,
#  8509,
#  1918,
#  74318,
#  7610,
#  5644,
#  3182,
#  120,
#  8254,
#  1121,
#  7334,
#  8566,
#  8660,
#  8682,
#  7708,
#  1353,
#  9101,
#  7408,
#  9192,
#  2552,
#  8657,
#  32617,
#  9272,
#  9374,
#  8222,
#  9499,
#  1985,
#  7292,
#  7290,
#  8223,
#  9509,
#  3087,
#  8901,
#  8263,
#  9567,
#  9241,
#  10920,
#  10996,
#  11072,
#  11118,
#  11077,
# ...

# %%
df[df.name=='PlayStation 4']
# Out:
#                          _id alternative_name     created_at  \
# 39  5bea4194933dea0e0b3dbbbe              PS4  1326544944299
#
#                                                 games  generation  id  \
# 39  [2033, 8500, 2957, 1979, 2920, 3152, 16735, 32...         8.0  48
#
#                                                  logo           name    slug  \
# 39  {'url': '//images.igdb.com/igdb/image/upload/t...  PlayStation 4  ps4--1
#
#                                               summary     updated_at  \
# 39  The PlayStation 4 system opens the door to an ...  1433175597593
#
#                                       url  \
# 39  https://www.igdb.com/platforms/ps4--1
#
#                                              versions  \
# 39  [{'name': 'Initial version', 'slug': 'initial-...
#
#                             website
# 39  http://www.playstation.com/ps4/
