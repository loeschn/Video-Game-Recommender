# %%
import requests
import pymongo
import pandas as pd
import pprint

# %%
class ScrapingException(Exception):
    pass

def api_request(url, params=None):
    """Make an IGDB API request."""
    headers = {'Accept': 'application/json', 
               "user-key": '1cca0ffb6c7bbc063e1ae12727218933'}
    response = requests.get(url, headers=headers, params=params)
    if response.status_code != 200:
        raise ScrapingException(f"Error: status code {response.status_code}\n\nContent:\n{response.content}")
    return response.json()

# %%
def api_games(game_id=""):
    """Get game data for game_id."""
    url = f"https://api-2445582011268.apicast.io/games/{game_id}"
    return api_request(url)

# %%
def api_platforms(platform_id=""):
    """Get platform data for platform_id."""
    url = f"https://api-2445582011268.apicast.io/platforms/{platform_id}"
    return api_request(url)

# %%
mc = pymongo.MongoClient()
db = mc['ps4_game_data']

# %%
games = db['games']
platform = db['platform']

# %%
ps4 = api_platforms(48)

# %%
ps4[0]
# Out:
# {'id': 48,
#  'name': 'PlayStation 4',
#  'logo': {'url': '//images.igdb.com/igdb/image/upload/t_thumb/kjp5zjzy8omfm8kgxarx.jpg',
#   'cloudinary_id': 'kjp5zjzy8omfm8kgxarx',
#   'width': 600,
#   'height': 102},
#  'slug': 'ps4--1',
#  'url': 'https://www.igdb.com/platforms/ps4--1',
#  'created_at': 1326544944299,
#  'updated_at': 1433175597593,
#  'website': 'http://www.playstation.com/ps4/',
#  'summary': 'The PlayStation 4 system opens the door to an incredible journey through immersive new gaming worlds and a deeply connected gaming community. PS4 puts gamers first with an astounding launch line-up and over 180 games in development. Play amazing top-tier blockbusters and innovative indie hits on PS4. Developer inspired, gamer focused.',
#  'alternative_name': 'PS4',
#  'generation': 8,
#  'games': [2033,
#   8500,
#   2957,
#   1979,
#   2920,
#   3152,
#   16735,
#   3256,
#   18655,
#   3094,
#   4,
#   16765,
#   6632,
#   4756,
#   4754,
#   1887,
#   6030,
#   4755,
#   21729,
#   4071,
#   386,
#   8992,
#   5895,
#   17522,
#   1968,
#   3042,
#   7574,
#   28513,
#   54489,
#   36300,
#   6008,
#   4844,
#   6976,
#   7380,
#   7587,
#   4674,
#   17145,
#   6147,
#   3188,
#   3146,
#   4845,
#   121,
#   5541,
#   5333,
#   5328,
#   7171,
#   7685,
#   27512,
#   7208,
#   5330,
#   5327,
#   4786,
#   7614,
#   1354,
#   8598,
#   8467,
#   1981,
#   7897,
#   14878,
#   11203,
#   3025,
#   2050,
#   6707,
#   1267,
#   19916,
#   8409,
#   52555,
#   3095,
#   8507,
#   8509,
#   1918,
#   74318,
#   7610,
#   5644,
#   3182,
#   120,
#   8254,
#   1121,
#   7334,
#   8566,
#   8660,
#   8682,
#   7708,
#   1353,
#   9101,
#   7408,
#   9192,
#   2552,
#   8657,
#   32617,
#   9272,
#   9374,
#   8222,
#   9499,
#   1985,
#   7292,
#   7290,
#   8223,
#   9509,
#   3087,
#   8901,
#   8263,
#   9567,
#   9241,
#   10920,
#   10996,
#   11072,
#   11118,
#   11077,
#   11160,
#   18978,
#   11218,
#   7609,
#   11198,
#   5639,
#   11393,
#   11502,
#   11006,
#   1983,
#   9023,
#   11588,
#   11594,
#   6781,
#   7405,
#   11052,
#   11260,
#   2113,
#   1938,
#   10324,
#   11185,
#   10472,
#   10728,
#   11790,
#   6804,
#   5592,
#   533,
#   11839,
#   11842,
#   17847,
#   13677,
#   18814,
#   11857,
#   11328,
#   112,
#   15853,
#   74552,
#   31792,
#   44280,
#   76726,
#   67625,
#   57003,
#   87742,
#   37067,
#   3102,
#   34567,
#   54218,
#   54217,
#   41620,
#   23993,
#   20861,
#   8173,
#   57002,
#   69346,
#   54524,
#   29545,
#   23479,
#   26401,
#   28289,
#   37143,
#   26933,
#   27159,
#   18182,
#   28540,
#   33309,
#   28044,
#   21317,
#   18157,
#   19525,
#   37094,
#   70833,
#   27283,
#   28170,
#   80963,
#   57021,
#   26546,
#   40237,
#   36662,
#   ...],
#  'versions': [{'name': 'Initial version',
#    'slug': 'initial-version-6835ddec-db2a-4da6-8f89-7d8e63f7e293',
#    'url': 'https://www.igdb.com/platforms/ps4--1/version/initial-version-6835ddec-db2a-4da6-8f89-7d8e63f7e293',
#    'summary': 'The PlayStation 4 system opens the door to an incredible journey through immersive new gaming worlds and a deeply connected gaming community. PS4 puts gamers first with an astounding launch line-up and over 180 games in development. Play amazing top-tier blockbusters and innovative indie hits on PS4. Developer inspired, gamer focused.',
#    'manufacturer': 2123,
#    'os': 'Orbis OS',
#    'cpu': 'Semi-custom 8-core AMD x86-64 CPU',
#    'storage': 'Hard drive, 500GB (user upgradeable, supports SSD)',
#    'memory': '8 GB GDDR5',
#    'graphics': 'Semi-custom AMD Radeon GPU',
#    'online': 'PlayStation Network',
#    'media': 'Blu-ray Disc, DVD',
#    'connectivity': '802.11 b/g/n Wireless, Bluetooth 2.1, USB 3.0, Ethernet 10/100/1000',
#    'manufacturers': [{'company': 2123}],
#    'developers': [{'company': 45}],
#    'logo': {'url': '//images.igdb.com/igdb/image/upload/t_thumb/zslgznczgg5lfrqxize5.png',
#     'cloudinary_id': 'zslgznczgg5lfrqxize5',
#     'width': 525,
#     'height': 201},
#    'release_dates': [{'date': 1384473600000, 'region': 2},
#     {'date': 1385683200000, 'region': 1},
#     {'date': 1385683200000, 'region': 3},
#     {'date': 1385683200000, 'region': 4}]},
#   {'name': 'PlayStation 4 Slim',
#    'slug': 'playstation-4-slim',
#    'url': 'https://www.igdb.com/platforms/ps4--1/version/playstation-4-slim',
#    'summary': '"When comparing the new PS4 model to the current model, we’ve reduced volume by 30 percent, weight by 16 percent, and power consumption by 28 percent. Despite the sleek design, the new model packs all of the same powerful components that have made PS4 the best place to play."',
#    'os': 'Orbis OS',
#    'cpu': 'x86-64 AMD "Jaguar", 8 cores',
#    'storage': '500gb',
#    'memory': 'GDDR5 8GB',
#    'graphics': '1.84 TFLOPS, AMD Radeon based graphics engine',
#    'online': 'PlayStation Network',
#    'media': 'BD × 6 CAV, DVD × 8 CAV',
#    'connectivity': 'Super-Speed USB (USB 3.1 Gen1) port × 2, AUX port × 1, Ethernet?10BASE-T, 100BASE-TX, 1000BASE-T?×, IEEE 802.11 a/b/g/n/ac wi-fi, Bluetooth v4.0',
#    'developers': [{'company': 4897}],
#    'release_dates': [{'date': 1473897600000, 'region': 8}]},
#   {'name': 'PlayStation 4 Pro',
#    'slug': 'playstation-4-pro',
#    'url': 'https://www.igdb.com/platforms/ps4--1/version/playstation-4-pro',
#    'summary': 'Also Known as the PS4 Neo and PS4.5\n\n"PS4 Pro is a high-end version of PS4 that is capable of outputting 4K graphics, HDR support, smoother and more stable framerates, and 4K video streaming. Upon its launch, PS4 Pro will make supported PS4 games look better and run more smoothly, while giving developers an upgraded toolset to create even richer, more detailed game worlds. How these powerful new tools are used is up to individual developers and the experience they are creating."',
#    'os': 'Orbis OS',
#    'cpu': 'x86-64 AMD "Jaguar," 8 cores',
#    'storage': '1 tb',
#    'memory': 'GDDR5 8GB',
#    'graphics': '4.20 TFLOPS, AMD Radeon™ based graphics engine',
#    'online': 'PlayStation Network',
#    'media': 'BD × 6 CAV, DVD × 8 CAV',
#    'connectivity': 'Super-Speed USB (USB 3.1 Gen.1) port × 3, AUX port × 1, Ethernet (10BASE-T, 100BASE-TX, 1000BASE-T)×1, IEEE 802.11 a/b/g/n/ac, Bluetooth® 4.0 (LE)',
#    'resolutions': 'capable of running at up to 4K (3840 x 2160 pixels, also known as “2160p”) resolution',
#    'developers': [{'company': 13634}],
#    'logo': {'url': '//images.igdb.com/igdb/image/upload/t_thumb/kjp5zjzy8omfm8kgxarx.png',
#     'cloudinary_id': 'kjp5zjzy8omfm8kgxarx',
#     'width': 600,
#     'height': 102},
#    'release_dates': [{'date': 1478736000000, 'region': 8}]}]}

# %%
platform.insert_one(ps4[0])

# %%
ps4_ids = (ps4[0]['games'])

# %%
len(ps4_ids)
# Out:
# 2470

# %%
for game_id in ps4_ids:
    games.insert_many(api_games(game_id))

# %%
def get_game_info(key="name", value=""):
    """Returns all game information for game given the key & value in the game dict"""
    return games.find_one({key : value})

# %%
get_game_info(value='Brawlhalla')
# Out:
# {'_id': ObjectId('5bf5d717933deaf65348d6ab'),
#  'id': 10233,
#  'name': 'Brawlhalla',
#  'slug': 'brawlhalla',
#  'url': 'https://www.igdb.com/games/brawlhalla',
#  'created_at': 1431326350526,
#  'updated_at': 1542514285739,
#  'summary': 'A 2D platform fighter where the best of the baddest-ass warriors in history battle each other in an eternal tourney of champions for bragging rights, infinite mead, and the pure pleasure of delivering a beatdown.',
#  'hypes': 3,
#  'rating': 70.2753841717009,
#  'popularity': 4.666666666666666,
#  'aggregated_rating': 75.0,
#  'aggregated_rating_count': 1,
#  'total_rating': 72.63769208585046,
#  'total_rating_count': 12,
#  'rating_count': 11,
#  'games': [18869,
#   23733,
#   14760,
#   10039,
#   3222,
#   36198,
#   14763,
#   22387,
#   56033,
#   17828],
#  'tags': [1,
#   17,
#   22,
#   268435460,
#   268435464,
#   268435488,
#   268435489,
#   536871019,
#   536872485,
#   536872486,
#   536875046,
#   536875066,
#   536875067,
#   536875173,
#   536875378,
#   536875680,
#   536875781,
#   536875783,
#   536875794,
#   536876239,
#   536876291,
#   536880160,
#   536888542,
#   536888543,
#   536888544,
#   1073741828],
#  'developers': [5531],
#  'publishers': [5531],
#  'game_engines': [63],
#  'category': 0,
#  'player_perspectives': [4],
#  'game_modes': [1, 2, 3],
#  'keywords': [107,
#   1573,
#   1574,
#   4134,
#   4154,
#   4155,
#   4261,
#   4466,
#   4768,
#   4869,
#   4871,
#   4882,
#   5327,
#   5379,
#   9248,
#   17630,
#   17631,
#   17632],
#  'themes': [1, 17, 22],
#  'genres': [4, 8, 32, 33],
#  'first_release_date': 1398816000000,
#  'pulse_count': 33,
#  'platforms': [45, 6, 14, 48, 49, 130],
#  'release_dates': [{'category': 0,
#    'platform': 130,
#    'date': 1541462400000,
#    'human': '2018-Nov-06',
#    'y': 2018,
#    'm': 11},
#   {'category': 0,
#    'platform': 49,
#    'date': 1541462400000,
#    'human': '2018-Nov-06',
#    'y': 2018,
#    'm': 11},
#   {'category': 0,
#    'platform': 45,
#    'date': 1508198400000,
#    'region': 1,
#    'human': '2017-Oct-17',
#    'y': 2017,
#    'm': 10},
#   {'category': 0,
#    'platform': 45,
#    'date': 1508198400000,
#    'region': 2,
#    'human': '2017-Oct-17',
#    'y': 2017,
#    'm': 10},
#   {'category': 0,
#    'platform': 48,
#    'date': 1498435200000,
#    'region': 2,
#    'human': '2017-Jun-26',
#    'y': 2017,
#    'm': 6},
#   {'category': 0,
#    'platform': 6,
#    'date': 1398816000000,
#    'region': 2,
#    'human': '2014-Apr-30',
#    'y': 2014,
#    'm': 4},
#   {'category': 0,
#    'platform': 48,
#    'date': 1508198400000,
#    'region': 8,
#    'human': '2017-Oct-17',
#    'y': 2017,
#    'm': 10},
#   {'category': 0,
#    'platform': 6,
#    'date': 1508198400000,
#    'region': 8,
#    'human': '2017-Oct-17',
#    'y': 2017,
#    'm': 10},
#   {'category': 0,
#    'platform': 14,
#    'date': 1508198400000,
#    'region': 8,
#    'human': '2017-Oct-17',
#    'y': 2017,
#    'm': 10}],
#  'screenshots': [{'url': '//images.igdb.com/igdb/image/upload/t_thumb/gtgstsnxw7ax76ruayvz.jpg',
#    'cloudinary_id': 'gtgstsnxw7ax76ruayvz',
#    'width': 1920,
#    'height': 1080},
#   {'url': '//images.igdb.com/igdb/image/upload/t_thumb/p2ldsxnrdqk6hcup13lf.jpg',
#    'cloudinary_id': 'p2ldsxnrdqk6hcup13lf',
#    'width': 1920,
#    'height': 1080},
#   {'url': '//images.igdb.com/igdb/image/upload/t_thumb/wjiyva3dd1jqmv2avvno.jpg',
#    'cloudinary_id': 'wjiyva3dd1jqmv2avvno',
#    'width': 1920,
#    'height': 1080},
#   {'url': '//images.igdb.com/igdb/image/upload/t_thumb/fbsltkil1dqw4z0inzy7.jpg',
#    'cloudinary_id': 'fbsltkil1dqw4z0inzy7',
#    'width': 1920,
#    'height': 1080},
#   {'url': '//images.igdb.com/igdb/image/upload/t_thumb/v7niniwb7hj61cft2ald.jpg',
#    'cloudinary_id': 'v7niniwb7hj61cft2ald',
#    'width': 1920,
#    'height': 1080}],
#  'videos': [{'name': 'Trailer', 'video_id': 'fnd71bqiiW0'},
#   {'name': 'Gameplay video', 'video_id': 'CqqBAVHDQWU'},
#   {'name': 'Trailer', 'video_id': 'hwXPeMPp1Ag'}],
#  'cover': {'url': '//images.igdb.com/igdb/image/upload/t_thumb/qoyijccswmzvxqemsxod.jpg',
#   'cloudinary_id': 'qoyijccswmzvxqemsxod',
#   'width': 600,
#   'height': 800},
#  'esrb': {'rating': 4},
#  'pegi': {'synopsis': 'The content of this game is suitable for persons aged 7 years and over only.',
#   'rating': 2},
#  'websites': [{'category': 9,
#    'url': 'https://www.youtube.com/user/Brawlhalla'},
#   {'category': 6, 'url': 'https://www.twitch.tv/brawlhalla'},
#   {'category': 3, 'url': 'https://en.wikipedia.org/wiki/Brawlhalla'},
#   {'category': 2,
#    'url': 'http://wiki.brawlhalla.com/w/Welcome_to_the_Official_Brawlhalla_Wiki!'},
#   {'category': 13, 'url': 'https://store.steampowered.com/app/291550'},
#   {'category': 1, 'url': 'http://www.brawlhalla.com'},
#   {'category': 5, 'url': 'https://twitter.com/brawlhalla'},
#   {'category': 4, 'url': 'https://www.facebook.com/Brawlhalla/'}],
#  'external': {'steam': '291550'}}
